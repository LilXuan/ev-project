# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import time

spark = SparkSession.builder \
    .appName("ACN_Preprocessing") \
    .config("spark.sql.shuffle.partitions", "16") \
    .config("spark.executor.memory", "3g") \
    .getOrCreate()

print("="*70)
print("STEP 1: LOAD RAW DATA")
print("="*70)

# Đọc toàn bộ dữ liệu thô (giữ nguyên các cột)
df_raw = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .parquet("hdfs://localhost:9000/ev-project/data/silver/ev_sessions/caltech/*")

print(f"Raw sessions: {df_raw.count():,}")
print(f"Raw columns: {df_raw.columns}")
df_raw.printSchema()
# Out:
# 26/04/17 14:05:05 WARN Utils: Your hostname, ax2 resolves to a loopback address: 127.0.1.1; using 192.168.40.130 instead (on interface ens33)
# 26/04/17 14:05:05 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/17 14:05:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ======================================================================
# STEP 1: LOAD RAW DATA
# ======================================================================
# 26/04/17 14:05:28 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# [Stage 2:>                                                          (0 + 4) / 4]
# Raw sessions: 31,424
# Raw columns: ['_batch_id', '_id', '_ingest_time', 'clusterID', 'connectionTime', 'disconnectTime', 'doneChargingTime', 'kWhDelivered', 'sessionID', 'siteID', 'spaceID', 'stationID', 'timezone', 'userID', 'userInputs']
# root
#  |-- _batch_id: string (nullable = true)
#  |-- _id: string (nullable = true)
#  |-- _ingest_time: string (nullable = true)
#  |-- clusterID: string (nullable = true)
#  |-- connectionTime: string (nullable = true)
#  |-- disconnectTime: string (nullable = true)
#  |-- doneChargingTime: string (nullable = true)
#  |-- kWhDelivered: double (nullable = true)
#  |-- sessionID: string (nullable = true)
#  |-- siteID: string (nullable = true)
#  |-- spaceID: string (nullable = true)
#  |-- stationID: string (nullable = true)
#  |-- timezone: string (nullable = true)
#  |-- userID: string (nullable = true)
#  |-- userInputs: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- WhPerMile: long (nullable = true)
#  |    |    |-- kWhRequested: double (nullable = true)
#  |    |    |-- milesRequested: long (nullable = true)
#  |    |    |-- minutesAvailable: long (nullable = true)
#  |    |    |-- modifiedAt: string (nullable = true)
#  |    |    |-- paymentRequired: boolean (nullable = true)
#  |    |    |-- requestedDeparture: string (nullable = true)
#  |    |    |-- userID: long (nullable = true)

# %%
print("="*70)
print("STEP 2: REMOVE ID COLUMNS")
print("="*70)

# Paper: "_id, sessionID, stationID, spaceID, siteID, clusterID, userID"
id_columns = ['_batch_id', '_id', '_ingest_time', 'sessionID', 
                        'stationID', 'spaceID', 'siteID', 'clusterID', 'userID']

# Kiểm tra xem có tồn tại không
existing_cols = [c for c in id_columns if c in df_raw.columns]
missing_cols = [c for c in id_columns if c not in df_raw.columns]

print(f"Removing: {existing_cols}")
if missing_cols:
    print(f"⚠️ Missing (already not in data): {missing_cols}")
    
df_step2 = df_raw.drop(*id_columns)

print(f"Removed columns: {id_columns}")
print(f"Remaining columns: {df_step2.columns}")
print(f"Row count: {df_step2.count():,}")
df_step2.printSchema()
# Out:
# ======================================================================
# STEP 2: REMOVE ID COLUMNS
# ======================================================================
# Removing: ['_batch_id', '_id', '_ingest_time', 'sessionID', 'stationID', 'spaceID', 'siteID', 'clusterID', 'userID']
# Removed columns: ['_batch_id', '_id', '_ingest_time', 'sessionID', 'stationID', 'spaceID', 'siteID', 'clusterID', 'userID']
# Remaining columns: ['connectionTime', 'disconnectTime', 'doneChargingTime', 'kWhDelivered', 'timezone', 'userInputs']
# [Stage 5:==============>                                            (1 + 3) / 4]
# Row count: 31,424
# root
#  |-- connectionTime: string (nullable = true)
#  |-- disconnectTime: string (nullable = true)
#  |-- doneChargingTime: string (nullable = true)
#  |-- kWhDelivered: double (nullable = true)
#  |-- timezone: string (nullable = true)
#  |-- userInputs: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- WhPerMile: long (nullable = true)
#  |    |    |-- kWhRequested: double (nullable = true)
#  |    |    |-- milesRequested: long (nullable = true)
#  |    |    |-- minutesAvailable: long (nullable = true)
#  |    |    |-- modifiedAt: string (nullable = true)
#  |    |    |-- paymentRequired: boolean (nullable = true)
#  |    |    |-- requestedDeparture: string (nullable = true)
#  |    |    |-- userID: long (nullable = true)

# %%
print("="*70)
print("STEP 3: CONVERT DATETIME TO TIMEZONE-NAIVE")
print("="*70)

# Kiểm tra format datetime hiện tại
print("📋 Raw datetime samples:")
df_step2.select("connectionTime", "disconnectTime", "doneChargingTime", "timezone").show(5, truncate=False)

# Paper: convert to timezone-naive format
# Dữ liệu có dạng: "2018-09-25 22:42:06-07:00"
# Dùng from_utc_timestamp để chuyển về UTC và bỏ timezone

df_step3 = df_step2 \
    .withColumn("conn_ts_with_tz", 
                to_timestamp(col("connectionTime"), "yyyy-MM-dd HH:mm:ssXXX")) \
    .withColumn("disc_ts_with_tz", 
                to_timestamp(col("disconnectTime"), "yyyy-MM-dd HH:mm:ssXXX")) \
    .withColumn("done_ts_with_tz", 
                to_timestamp(col("doneChargingTime"), "yyyy-MM-dd HH:mm:ssXXX"))

# Chuyển về UTC (bỏ timezone)
df_step3 = df_step3 \
    .withColumn("connectionTime_utc", 
                from_utc_timestamp(col("conn_ts_with_tz"), "UTC")) \
    .withColumn("disconnectTime_utc", 
                from_utc_timestamp(col("disc_ts_with_tz"), "UTC")) \
    .withColumn("doneChargingTime_utc", 
                from_utc_timestamp(col("done_ts_with_tz"), "UTC")) \
    .drop("connectionTime", "disconnectTime", "doneChargingTime", "timezone",
          "conn_ts_with_tz", "disc_ts_with_tz", "done_ts_with_tz")

print("\n✅ After conversion (timezone-naive UTC):")
df_step3.select("connectionTime_utc", "disconnectTime_utc", "doneChargingTime_utc").show(5, truncate=False)

# Kiểm tra null counts
null_counts = df_step3.select(
    sum(col("connectionTime_utc").isNull().cast("int")).alias("conn_null"),
    sum(col("disconnectTime_utc").isNull().cast("int")).alias("disc_null"),
    sum(col("doneChargingTime_utc").isNull().cast("int")).alias("done_null")
).collect()[0]

print(f"\n📊 Null counts after conversion:")
print(f"  connectionTime_utc null: {null_counts['conn_null']:,}")
print(f"  disconnectTime_utc null: {null_counts['disc_null']:,}")
print(f"  doneChargingTime_utc null: {null_counts['done_null']:,}")

# Kiểm tra time range
print("\n📅 Time range:")
df_step3.select(
    min("connectionTime_utc").alias("earliest"),
    max("connectionTime_utc").alias("latest")
).show()

print(f"\n✅ Remaining columns: {df_step3.columns}")
print(f"✅ Row count: {df_step3.count():,}")

# Bỏ userInputs (paper không dùng)
df_step3 = df_step3.drop("userInputs")
print(f"\n✅ Dropped 'userInputs' (not used in paper)")
print(f"✅ Final columns for next step: {df_step3.columns}")
# Out:
# ======================================================================
# STEP 3: CONVERT DATETIME TO TIMEZONE-NAIVE
# ======================================================================
# 📋 Raw datetime samples:
# +-------------------------+-------------------------+-------------------------+-------------------+
# |connectionTime           |disconnectTime           |doneChargingTime         |timezone           |
# +-------------------------+-------------------------+-------------------------+-------------------+
# |2018-09-25 22:42:06-07:00|2018-09-25 22:54:07-07:00|2018-09-25 22:54:03-07:00|America/Los_Angeles|
# |2018-09-25 22:03:35-07:00|2018-09-25 22:18:53-07:00|2018-09-25 22:18:49-07:00|America/Los_Angeles|
# |2018-09-25 21:35:26-07:00|2018-09-26 07:33:41-07:00|2018-09-26 07:01:30-07:00|America/Los_Angeles|
# |2018-09-25 21:34:24-07:00|2018-09-25 22:26:26-07:00|2018-09-25 22:21:37-07:00|America/Los_Angeles|
# |2018-09-25 20:36:28-07:00|2018-09-26 09:43:48-07:00|2018-09-25 22:45:03-07:00|America/Los_Angeles|
# +-------------------------+-------------------------+-------------------------+-------------------+
# only showing top 5 rows
#
#
# ✅ After conversion (timezone-naive UTC):
# +-------------------+-------------------+--------------------+
# |connectionTime_utc |disconnectTime_utc |doneChargingTime_utc|
# +-------------------+-------------------+--------------------+
# |2018-09-26 05:42:06|2018-09-26 05:54:07|2018-09-26 05:54:03 |
# |2018-09-26 05:03:35|2018-09-26 05:18:53|2018-09-26 05:18:49 |
# |2018-09-26 04:35:26|2018-09-26 14:33:41|2018-09-26 14:01:30 |
# |2018-09-26 04:34:24|2018-09-26 05:26:26|2018-09-26 05:21:37 |
# |2018-09-26 03:36:28|2018-09-26 16:43:48|2018-09-26 05:45:03 |
# +-------------------+-------------------+--------------------+
# only showing top 5 rows
# 📊 Null counts after conversion:
#   connectionTime_utc null: 0
#   disconnectTime_utc null: 0
#   doneChargingTime_utc null: 2,055
#
# 📅 Time range:
# +-------------------+-------------------+
# |           earliest|             latest|
# +-------------------+-------------------+
# |2018-04-25 11:08:04|2021-09-14 01:52:37|
# +-------------------+-------------------+
#
#
# ✅ Remaining columns: ['kWhDelivered', 'userInputs', 'connectionTime_utc', 'disconnectTime_utc', 'doneChargingTime_utc']
# ✅ Row count: 31,424
#
# ✅ Dropped 'userInputs' (not used in paper)
# ✅ Final columns for next step: ['kWhDelivered', 'connectionTime_utc', 'disconnectTime_utc', 'doneChargingTime_utc']

# %%
print("="*70)
print("STEP 4: DURATION FEATURES (in hours)")
print("="*70)

from pyspark.sql.functions import unix_timestamp, col, log1p, when

# Paper: duration = disconnectTime - connectionTime (hours)
# Paper: charging_duration = doneChargingTime - connectionTime (hours)

df_step4 = df_step3 \
    .withColumn("duration", 
                (unix_timestamp(col("disconnectTime_utc")) - 
                 unix_timestamp(col("connectionTime_utc"))) / 3600) \
    .withColumn("charging_duration", 
                when(col("doneChargingTime_utc").isNotNull(),
                     (unix_timestamp(col("doneChargingTime_utc")) - 
                      unix_timestamp(col("connectionTime_utc"))) / 3600)
                .otherwise(None))

# Log transform of charging_duration (paper: charging_duration_log)
df_step4 = df_step4 \
    .withColumn("charging_duration_log", 
                when(col("charging_duration") > 0, log1p(col("charging_duration")))
                .otherwise(None))

print("📊 Duration statistics (hours):")
df_step4.select("duration", "charging_duration", "charging_duration_log").describe().show()

print("\n📋 Sample duration features (first 10 rows):")
df_step4.select(
    "connectionTime_utc", "disconnectTime_utc", "doneChargingTime_utc",
    "duration", "charging_duration", "charging_duration_log"
).show(10, truncate=False)

# Kiểm tra giá trị không hợp lệ
print("\n📊 Data quality checks:")
invalid_duration = df_step4.filter(col("duration") < 0).count()
invalid_charging = df_step4.filter(col("charging_duration") < 0).count()
print(f"  Negative duration: {invalid_duration:,}")
print(f"  Negative charging_duration: {invalid_charging:,}")

# Kiểm tra phân bố
print("\n📊 Duration distribution (hours):")
df_step4.select("duration").summary("min", "25%", "50%", "75%", "max").show()

print(f"\n✅ Remaining columns: {df_step4.columns}")
print(f"✅ Row count: {df_step4.count():,}")
# Out:
# ======================================================================
# STEP 4: DURATION FEATURES (in hours)
# ======================================================================
# 📊 Duration statistics (hours):
# +-------+--------------------+-------------------+---------------------+
# |summary|            duration|  charging_duration|charging_duration_log|
# +-------+--------------------+-------------------+---------------------+
# |  count|               31424|              29369|                29341|
# |   mean|   5.652122086444909| 2.9775439333234828|   1.1978547438016065|
# | stddev|   5.963686144541357| 3.4296022505991206|   0.5716383654504634|
# |    min|0.034444444444444444|-0.6894444444444444| 8.329863038918628E-4|
# |    max|  245.26916666666668| 200.01583333333335|    5.303383677759315|
# +-------+--------------------+-------------------+---------------------+
#
#
# 📋 Sample duration features (first 10 rows):
# +-------------------+-------------------+--------------------+-------------------+-------------------+---------------------+
# |connectionTime_utc |disconnectTime_utc |doneChargingTime_utc|duration           |charging_duration  |charging_duration_log|
# +-------------------+-------------------+--------------------+-------------------+-------------------+---------------------+
# |2018-09-26 05:42:06|2018-09-26 05:54:07|2018-09-26 05:54:03 |0.20027777777777778|0.19916666666666666|0.18162687111127612  |
# |2018-09-26 05:03:35|2018-09-26 05:18:53|2018-09-26 05:18:49 |0.255              |0.2538888888888889 |0.22624983293327963  |
# |2018-09-26 04:35:26|2018-09-26 14:33:41|2018-09-26 14:01:30 |9.970833333333333  |9.434444444444445  |2.345112299480303    |
# |2018-09-26 04:34:24|2018-09-26 05:26:26|2018-09-26 05:21:37 |0.8672222222222222 |0.7869444444444444 |0.580507146966799    |
# |2018-09-26 03:36:28|2018-09-26 16:43:48|2018-09-26 05:45:03 |13.122222222222222 |2.1430555555555557 |1.1451954336234365   |
# |2018-09-26 03:24:09|2018-09-26 05:32:09|2018-09-26 04:41:42 |2.1333333333333333 |1.2925             |0.8296429251484829   |
# |2018-09-26 03:18:41|2018-09-26 05:58:06|2018-09-26 05:26:14 |2.6569444444444446 |2.1258333333333335 |1.1397009143057957   |
# |2018-09-26 03:03:46|2018-09-26 06:02:57|2018-09-26 05:06:31 |2.986388888888889  |2.0458333333333334 |1.1137745364077873   |
# |2018-09-26 03:00:15|2018-09-26 05:25:04|2018-09-26 04:54:59 |2.413611111111111  |1.9122222222222223 |1.0689164399990956   |
# |2018-09-26 02:57:56|2018-09-26 15:25:36|2018-09-26 07:39:21 |12.46111111111111  |4.690277777777778  |1.7387590655367702   |
# +-------------------+-------------------+--------------------+-------------------+-------------------+---------------------+
# only showing top 10 rows
#
#
# 📊 Data quality checks:
#   Negative duration: 0
#   Negative charging_duration: 26
#
# 📊 Duration distribution (hours):
# +-------+--------------------+
# |summary|            duration|
# +-------+--------------------+
# |    min|0.034444444444444444|
# |    25%|  1.8663888888888889|
# |    50%|   4.729722222222223|
# |    75%|   8.465833333333334|
# |    max|  245.26916666666668|
# +-------+--------------------+
#
#
# ✅ Remaining columns: ['kWhDelivered', 'connectionTime_utc', 'disconnectTime_utc', 'doneChargingTime_utc', 'duration', 'charging_duration', 'charging_duration_log']
# ✅ Row count: 31,424

# %%
print("="*70)
print("STEP 5: TEMPORAL FEATURES")
print("="*70)

from pyspark.sql.functions import hour, dayofweek, month, year, dayofyear, weekofyear
from pyspark.sql.functions import sin, cos, pi, when

df_step5 = df_step4

# Basic time features
df_step5 = df_step5 \
    .withColumn("hour", hour(col("connectionTime_utc"))) \
    .withColumn("day_of_week", dayofweek(col("connectionTime_utc")) - 1) \
    .withColumn("month", month(col("connectionTime_utc"))) \
    .withColumn("year", year(col("connectionTime_utc"))) \
    .withColumn("day_of_year", dayofyear(col("connectionTime_utc"))) \
    .withColumn("week_of_year", weekofyear(col("connectionTime_utc")))

# Season (paper: 0=Winter,1=Spring,2=Summer,3=Fall)
df_step5 = df_step5.withColumn("season",
    when(col("month").isin([12, 1, 2]), 0)
    .when(col("month").isin([3, 4, 5]), 1)
    .when(col("month").isin([6, 7, 8]), 2)
    .otherwise(3)  # 9,10,11 = Fall
)

# is_weekend (paper: 1 for Saturday/Sunday)
df_step5 = df_step5.withColumn("is_weekend", 
    when(col("day_of_week") >= 5, 1).otherwise(0))

# is_holiday (paper: 1 for December/January)
df_step5 = df_step5.withColumn("is_holiday",
    when(col("month").isin([12, 1]), 1).otherwise(0))

# Cyclical features for hour
df_step5 = df_step5 \
    .withColumn("hour_sin", sin(2 * pi() * col("hour") / 24)) \
    .withColumn("hour_cos", cos(2 * pi() * col("hour") / 24))

print("✅ Temporal features added:")
print(f"  - hour: 0-23")
print(f"  - day_of_week: 0-6 (0=Monday)")
print(f"  - month: 1-12")
print(f"  - year: {df_step5.select('year').distinct().orderBy('year').collect()}")
print(f"  - day_of_year: 1-365/366")
print(f"  - week_of_year: 1-52/53")
print(f"  - season: 0=Winter,1=Spring,2=Summer,3=Fall")
print(f"  - is_weekend: 0/1")
print(f"  - is_holiday: 0/1 (1 for Dec/Jan)")
print(f"  - hour_sin, hour_cos: circular encoding")

# Sample data
print("\n📋 Sample temporal features (first 10 rows):")
df_step5.select(
    "connectionTime_utc", "hour", "day_of_week", "month", "year",
    "day_of_year", "week_of_year", "season", "is_weekend", "is_holiday",
    "hour_sin", "hour_cos"
).show(10, truncate=False)

# Verify is_holiday logic
print("\n📊 is_holiday distribution:")
df_step5.groupBy("month", "is_holiday").count().orderBy("month").show(13)

print(f"\n✅ Remaining columns: {len(df_step5.columns)} columns")
print(f"✅ Row count: {df_step5.count():,}")
# Out:
# ======================================================================
# STEP 5: TEMPORAL FEATURES
# ======================================================================
# ✅ Temporal features added:
#   - hour: 0-23
#   - day_of_week: 0-6 (0=Monday)
#   - month: 1-12
#   - year: [Row(year=2018), Row(year=2019), Row(year=2020), Row(year=2021)]
#   - day_of_year: 1-365/366
#   - week_of_year: 1-52/53
#   - season: 0=Winter,1=Spring,2=Summer,3=Fall
#   - is_weekend: 0/1
#   - is_holiday: 0/1 (1 for Dec/Jan)
#   - hour_sin, hour_cos: circular encoding
#
# 📋 Sample temporal features (first 10 rows):
# +-------------------+----+-----------+-----+----+-----------+------------+------+----------+----------+-------------------+-------------------+
# |connectionTime_utc |hour|day_of_week|month|year|day_of_year|week_of_year|season|is_weekend|is_holiday|hour_sin           |hour_cos           |
# +-------------------+----+-----------+-----+----+-----------+------------+------+----------+----------+-------------------+-------------------+
# |2018-09-26 05:42:06|5   |3          |9    |2018|269        |39          |3     |0         |0         |0.9659258262890683 |0.25881904510252074|
# |2018-09-26 05:03:35|5   |3          |9    |2018|269        |39          |3     |0         |0         |0.9659258262890683 |0.25881904510252074|
# |2018-09-26 04:35:26|4   |3          |9    |2018|269        |39          |3     |0         |0         |0.8660254037844386 |0.5000000000000001 |
# |2018-09-26 04:34:24|4   |3          |9    |2018|269        |39          |3     |0         |0         |0.8660254037844386 |0.5000000000000001 |
# |2018-09-26 03:36:28|3   |3          |9    |2018|269        |39          |3     |0         |0         |0.7071067811865475 |0.7071067811865476 |
# |2018-09-26 03:24:09|3   |3          |9    |2018|269        |39          |3     |0         |0         |0.7071067811865475 |0.7071067811865476 |
# |2018-09-26 03:18:41|3   |3          |9    |2018|269        |39          |3     |0         |0         |0.7071067811865475 |0.7071067811865476 |
# |2018-09-26 03:03:46|3   |3          |9    |2018|269        |39          |3     |0         |0         |0.7071067811865475 |0.7071067811865476 |
# |2018-09-26 03:00:15|3   |3          |9    |2018|269        |39          |3     |0         |0         |0.7071067811865475 |0.7071067811865476 |
# |2018-09-26 02:57:56|2   |3          |9    |2018|269        |39          |3     |0         |0         |0.49999999999999994|0.8660254037844387 |
# +-------------------+----+-----------+-----+----+-----------+------------+------+----------+----------+-------------------+-------------------+
# only showing top 10 rows
#
#
# 📊 is_holiday distribution:
# +-----+----------+-----+
# |month|is_holiday|count|
# +-----+----------+-----+
# |    1|         1| 1983|
# |    2|         0| 1964|
# |    3|         0| 1594|
# |    4|         0| 1615|
# |    5|         0| 3099|
# |    6|         0| 3216|
# |    7|         0| 3371|
# |    8|         0| 3901|
# |    9|         0| 3439|
# |   10|         0| 3338|
# |   11|         0| 2176|
# |   12|         1| 1728|
# +-----+----------+-----+
#
#
# ✅ Remaining columns: 18 columns
# ✅ Row count: 31,424

# %%
# Step 5: Thêm interaction terms (nếu paper yêu cầu)
df_step5 = df_step5 \
    .withColumn("hour_charging_interaction", 
                col("hour") * col("charging_duration_log")) \
    .withColumn("weekend_charging_interaction",
                col("is_weekend") * col("charging_duration_log"))

# %%
print("="*70)
print("STEP 6: LAG FEATURES (global time order, NO stationID)")
print("="*70)

from pyspark.sql.window import Window
from pyspark.sql.functions import lag, col

# Paper: lag features on charging_duration_log
# Sắp xếp theo thời gian TOÀN CỤC, không partition theo station

window_lag_global = Window.orderBy("connectionTime_utc")

# Tạo lag features (1, 2, 3 periods behind)
df_step6 = df_step5 \
    .withColumn("lag_1_log", lag("charging_duration_log", 1).over(window_lag_global)) \
    .withColumn("lag_2_log", lag("charging_duration_log", 2).over(window_lag_global)) \
    .withColumn("lag_3_log", lag("charging_duration_log", 3).over(window_lag_global))

print("✅ Lag features created (global time order):")
print("  - lag_1_log: charging_duration_log của session trước đó")
print("  - lag_2_log: charging_duration_log của 2 session trước")
print("  - lag_3_log: charging_duration_log của 3 session trước")
print("  ⚠️ NO partition by stationID (paper doesn't mention it)")

# Kiểm tra kết quả
print("\n📋 Sample lag features (first 20 rows):")
df_step6.select(
    "connectionTime_utc", "charging_duration_log",
    "lag_1_log", "lag_2_log", "lag_3_log"
).show(20, truncate=False)

# Kiểm tra null counts (chỉ 3 sessions đầu tiên bị null)
null_counts = df_step6.select(
    sum(col("lag_1_log").isNull().cast("int")).alias("lag1_null"),
    sum(col("lag_2_log").isNull().cast("int")).alias("lag2_null"),
    sum(col("lag_3_log").isNull().cast("int")).alias("lag3_null")
).collect()[0]

print(f"\n📊 Null counts:")
print(f"  lag_1_log null: {null_counts['lag1_null']:,} (first session only)")
print(f"  lag_2_log null: {null_counts['lag2_null']:,} (first 2 sessions)")
print(f"  lag_3_log null: {null_counts['lag3_null']:,} (first 3 sessions)")

print(f"\n✅ Remaining columns: {len(df_step6.columns)} columns")
print(f"✅ Row count: {df_step6.count():,}")
# Out:
# ======================================================================
# STEP 6: LAG FEATURES (global time order, NO stationID)
# ======================================================================
# ✅ Lag features created (global time order):
#   - lag_1_log: charging_duration_log của session trước đó
#   - lag_2_log: charging_duration_log của 2 session trước
#   - lag_3_log: charging_duration_log của 3 session trước
#   ⚠️ NO partition by stationID (paper doesn't mention it)
#
# 📋 Sample lag features (first 20 rows):
# 26/04/17 14:07:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:01 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:02 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------------------+---------------------+------------------+------------------+------------------+
# |connectionTime_utc |charging_duration_log|lag_1_log         |lag_2_log         |lag_3_log         |
# +-------------------+---------------------+------------------+------------------+------------------+
# |2018-04-25 11:08:04|1.168863627212368    |NULL              |NULL              |NULL              |
# |2018-04-25 13:45:10|1.3824676039712638   |1.168863627212368 |NULL              |NULL              |
# |2018-04-25 13:45:50|0.7411433788282008   |1.3824676039712638|1.168863627212368 |NULL              |
# |2018-04-25 14:37:06|0.9046678920461622   |0.7411433788282008|1.3824676039712638|1.168863627212368 |
# |2018-04-25 14:40:34|1.38601654475472     |0.9046678920461622|0.7411433788282008|1.3824676039712638|
# |2018-04-25 14:43:50|0.9467121608674877   |1.38601654475472  |0.9046678920461622|0.7411433788282008|
# |2018-04-25 14:47:42|1.5404450409471488   |0.9467121608674877|1.38601654475472  |0.9046678920461622|
# |2018-04-25 14:58:25|1.0418459548175008   |1.5404450409471488|0.9467121608674877|1.38601654475472  |
# |2018-04-25 15:10:52|0.6683990108707513   |1.0418459548175008|1.5404450409471488|0.9467121608674877|
# |2018-04-25 15:12:11|1.4591962491035575   |0.6683990108707513|1.0418459548175008|1.5404450409471488|
# |2018-04-25 15:14:06|1.4633839948106873   |1.4591962491035575|0.6683990108707513|1.0418459548175008|
# |2018-04-25 15:14:41|0.7218965938459312   |1.4633839948106873|1.4591962491035575|0.6683990108707513|
# |2018-04-25 15:14:49|0.8973344130246008   |0.7218965938459312|1.4633839948106873|1.4591962491035575|
# |2018-04-25 15:20:56|0.5761450898866333   |0.8973344130246008|0.7218965938459312|1.4633839948106873|
# |2018-04-25 15:30:31|1.483244609417747    |0.5761450898866333|0.8973344130246008|0.7218965938459312|
# |2018-04-25 15:31:42|1.3663042162433883   |1.483244609417747 |0.5761450898866333|0.8973344130246008|
# |2018-04-25 15:33:45|1.1838551274068352   |1.3663042162433883|1.483244609417747 |0.5761450898866333|
# |2018-04-25 15:44:42|1.0730095398071233   |1.1838551274068352|1.3663042162433883|1.483244609417747 |
# |2018-04-25 15:48:23|1.1924904672169019   |1.0730095398071233|1.1838551274068352|1.3663042162433883|
# |2018-04-25 15:51:21|1.1288001630490245   |1.1924904672169019|1.0730095398071233|1.1838551274068352|
# +-------------------+---------------------+------------------+------------------+------------------+
# only showing top 20 rows
# 26/04/17 14:07:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:03 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 📊 Null counts:
#   lag_1_log null: 2,083 (first session only)
#   lag_2_log null: 2,084 (first 2 sessions)
#   lag_3_log null: 2,084 (first 3 sessions)
#
# ✅ Remaining columns: 21 columns
# ✅ Row count: 31,424

# %%
from pyspark.sql.functions import avg

# Thêm Rolling Mean vào df_step6
df_step6 = df_step6 \
    .withColumn("rolling_mean_3_log", 
                avg(col("charging_duration_log")).over(window_lag_global.rowsBetween(-3, -1))) \
    .withColumn("rolling_mean_5_log", 
                avg(col("charging_duration_log")).over(window_lag_global.rowsBetween(-5, -1)))

# %%
print("="*70)
print("STEP 7: ROLLING MEAN FEATURES")
print("="*70)

from pyspark.sql.window import Window
from pyspark.sql.functions import avg, col

# Paper: rolling_mean_3_log và rolling_mean_5_log
# Dựa trên charging_duration_log
# Window: 3 và 5 periods trước đó (không tính period hiện tại)

window_roll3 = Window.orderBy("connectionTime_utc").rowsBetween(-3, -1)
window_roll5 = Window.orderBy("connectionTime_utc").rowsBetween(-5, -1)

df_step7 = df_step6 \
    .withColumn("rolling_mean_3_log", avg("charging_duration_log").over(window_roll3)) \
    .withColumn("rolling_mean_5_log", avg("charging_duration_log").over(window_roll5))

print("✅ Rolling mean features created:")
print("  - rolling_mean_3_log: average of charging_duration_log of 3 previous sessions")
print("  - rolling_mean_5_log: average of charging_duration_log of 5 previous sessions")

# Kiểm tra kết quả
print("\n📋 Sample rolling mean features (first 20 rows):")
df_step7.select(
    "connectionTime_utc", "charging_duration_log",
    "rolling_mean_3_log", "rolling_mean_5_log"
).show(20, truncate=False)

# Kiểm tra null counts (các session đầu tiên sẽ bị null)
null_counts = df_step7.select(
    sum(col("rolling_mean_3_log").isNull().cast("int")).alias("roll3_null"),
    sum(col("rolling_mean_5_log").isNull().cast("int")).alias("roll5_null")
).collect()[0]

print(f"\n📊 Null counts:")
print(f"  rolling_mean_3_log null: {null_counts['roll3_null']:,} (first 3 sessions)")
print(f"  rolling_mean_5_log null: {null_counts['roll5_null']:,} (first 5 sessions)")

# Thống kê rolling mean
print("\n📊 Rolling mean statistics (non-null values):")
df_step7.filter(col("rolling_mean_3_log").isNotNull()).select(
    "rolling_mean_3_log", "rolling_mean_5_log"
).describe().show()

print(f"\n✅ Remaining columns: {len(df_step7.columns)} columns")
print(f"✅ Row count: {df_step7.count():,}")

# Hiển thị danh sách columns hiện tại
print("\n📋 Current columns:")
for i, col_name in enumerate(df_step7.columns):
    print(f"  {i+1:2}. {col_name}")
# Out:
# ======================================================================
# STEP 7: ROLLING MEAN FEATURES
# ======================================================================
# ✅ Rolling mean features created:
#   - rolling_mean_3_log: average of charging_duration_log of 3 previous sessions
#   - rolling_mean_5_log: average of charging_duration_log of 5 previous sessions
#
# 📋 Sample rolling mean features (first 20 rows):
# 26/04/17 14:07:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------------------+---------------------+------------------+------------------+
# |connectionTime_utc |charging_duration_log|rolling_mean_3_log|rolling_mean_5_log|
# +-------------------+---------------------+------------------+------------------+
# |2018-04-25 11:08:04|1.168863627212368    |NULL              |NULL              |
# |2018-04-25 13:45:10|1.3824676039712638   |1.168863627212368 |1.168863627212368 |
# |2018-04-25 13:45:50|0.7411433788282008   |1.2756656155918158|1.2756656155918158|
# |2018-04-25 14:37:06|0.9046678920461622   |1.0974915366706108|1.0974915366706108|
# |2018-04-25 14:40:34|1.38601654475472     |1.009426291615209 |1.0492856255144987|
# |2018-04-25 14:43:50|0.9467121608674877   |1.010609271876361 |1.116631809362543 |
# |2018-04-25 14:47:42|1.5404450409471488   |1.07913219922279  |1.072201516093567 |
# |2018-04-25 14:58:25|1.0418459548175008   |1.2910579155231188|1.103797003488744 |
# |2018-04-25 15:10:52|0.6683990108707513   |1.1763343855440456|1.163937518686604 |
# |2018-04-25 15:12:11|1.4591962491035575   |1.0835633355451337|1.1166837424515217|
# |2018-04-25 15:14:06|1.4633839948106873   |1.0564804049306031|1.1313196833212893|
# |2018-04-25 15:14:41|0.7218965938459312   |1.196993084928332 |1.2346540501099292|
# |2018-04-25 15:14:49|0.8973344130246008   |1.2148256125867254|1.0709443606896856|
# |2018-04-25 15:20:56|0.5761450898866333   |1.0275383338937398|1.0420420523311056|
# |2018-04-25 15:30:31|1.483244609417747    |0.7317920322523884|1.023591268134282 |
# |2018-04-25 15:31:42|1.3663042162433883   |0.9855747041096604|1.02840094019712  |
# |2018-04-25 15:33:45|1.1838551274068352   |1.1418979718492561|1.0089849844836603|
# |2018-04-25 15:44:42|1.0730095398071233   |1.3444679843559904|1.101376691195841 |
# |2018-04-25 15:48:23|1.1924904672169019   |1.207722961152449 |1.1365117165523453|
# |2018-04-25 15:51:21|1.1288001630490245   |1.1497850448102869|1.2597807920183992|
# +-------------------+---------------------+------------------+------------------+
# only showing top 20 rows
# 26/04/17 14:07:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 📊 Null counts:
#   rolling_mean_3_log null: 1,058 (first 3 sessions)
#   rolling_mean_5_log null: 856 (first 5 sessions)
#
# 📊 Rolling mean statistics (non-null values):
# 26/04/17 14:07:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/17 14:07:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------+-------------------+-------------------+
# |summary| rolling_mean_3_log| rolling_mean_5_log|
# +-------+-------------------+-------------------+
# |  count|              30366|              30366|
# |   mean|  1.189184244175747| 1.1895577362653835|
# | stddev|0.37868509320069643| 0.3218848866107085|
# |    min|0.08872287450480301|0.18324705431489752|
# |    max|  3.506716218119916|  3.506716218119916|
# +-------+-------------------+-------------------+
#
#
# ✅ Remaining columns: 23 columns
# ✅ Row count: 31,424
#
# 📋 Current columns:
#    1. kWhDelivered
#    2. connectionTime_utc
#    3. disconnectTime_utc
#    4. doneChargingTime_utc
#    5. duration
#    6. charging_duration
#    7. charging_duration_log
#    8. hour
#    9. day_of_week
#   10. month
#   11. year
#   12. day_of_year
#   13. week_of_year
#   14. season
#   15. is_weekend
#   16. is_holiday
#   17. hour_sin
#   18. hour_cos
#   19. lag_1_log
#   20. lag_2_log
#   21. lag_3_log
#   22. rolling_mean_3_log
#   23. rolling_mean_5_log

# %%
print("="*70)
print("STEP 8: OUTLIER REMOVAL USING IQR (PAPER'S METHOD)")
print("="*70)

from pyspark.sql.functions import col, expr

def remove_outliers_iqr(df, column_name, verbose=True):
    """Remove outliers using IQR method (Paper: exactly as described)"""
    
    # Calculate quantiles
    quantiles = df.approxQuantile(column_name, [0.25, 0.75], 0.01)
    q1 = quantiles[0]
    q3 = quantiles[1]
    iqr = q3 - q1
    
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    if verbose:
        print(f"\n  {column_name}:")
        print(f"    Q1 = {q1:.4f}, Q3 = {q3:.4f}, IQR = {iqr:.4f}")
        print(f"    Lower bound = {lower_bound:.4f}, Upper bound = {upper_bound:.4f}")
    
    # Count outliers
    before_count = df.count()
    outliers = df.filter((col(column_name) < lower_bound) | (col(column_name) > upper_bound))
    outlier_count = outliers.count()
    
    if verbose:
        print(f"    Outliers found: {outlier_count:,} ({100*outlier_count/before_count:.2f}%)")
    
    # Filter outliers
    df_clean = df.filter((col(column_name) >= lower_bound) & (col(column_name) <= upper_bound))
    
    return df_clean, outlier_count

# Create copy for outlier processing
df_step8 = df_step7

print("\n📊 Removing outliers from DURATION (hours):")
df_step8, dur_outliers = remove_outliers_iqr(df_step8, "duration")

print("\n📊 Removing outliers from CHARGING_DURATION (hours):")
df_step8, charge_outliers = remove_outliers_iqr(df_step8, "charging_duration")

print("\n📊 Removing outliers from KWHDELIVERED (target):")
df_step8, kwh_outliers = remove_outliers_iqr(df_step8, "kWhDelivered")

# Summary
print("\n" + "="*50)
print("📊 OUTLIER REMOVAL SUMMARY:")
print(f"  duration outliers removed: {dur_outliers:,}")
print(f"  charging_duration outliers removed: {charge_outliers:,}")
print(f"  kWhDelivered outliers removed: {kwh_outliers:,}")

print(f"\n✅ Before outlier removal: {df_step7.count():,} rows")
print(f"✅ After outlier removal: {df_step8.count():,} rows")
print(f"✅ Total rows removed: {df_step7.count() - df_step8.count():,}")

# Check statistics after outlier removal
print("\n📊 STATISTICS AFTER OUTLIER REMOVAL:")
df_step8.select("duration", "charging_duration", "kWhDelivered").describe().show()

# Paper: KEEPS negative values (does NOT filter them)
print("\n📊 DATA QUALITY CHECK AFTER OUTLIER REMOVAL (Paper keeps negatives):")
negative_check = df_step8.select(
    sum((col("duration") < 0).cast("int")).alias("neg_duration"),
    sum((col("charging_duration") < 0).cast("int")).alias("neg_charging"),
    sum((col("kWhDelivered") < 0).cast("int")).alias("neg_kwh")
).collect()[0]

print(f"  Negative duration: {negative_check['neg_duration']:,} (Paper keeps these)")
print(f"  Negative charging_duration: {negative_check['neg_charging']:,} (Paper keeps these)")
print(f"  Negative kWhDelivered: {negative_check['neg_kwh']:,}")

print(f"\n✅ Remaining columns: {len(df_step8.columns)} columns")
print(f"✅ Row count: {df_step8.count():,}")
# Out:
# ======================================================================
# STEP 8: OUTLIER REMOVAL USING IQR
# ======================================================================
#
# 📊 Removing outliers from DURATION (hours):
#   duration:
#     Q1 = 1.8708, Q3 = 8.3819, IQR = 6.5111
#     Lower bound = -7.8958, Upper bound = 18.1486
#     Outliers found: 443 (1.41%)
#
# 📊 Removing outliers from CHARGING_DURATION (hours):
#   charging_duration:
#     Q1 = 1.1528, Q3 = 3.7308, IQR = 2.5781
#     Lower bound = -2.7143, Upper bound = 7.5979
#     Outliers found: 1,981 (6.39%)
#
# 📊 Removing outliers from KWHDELIVERED (target):
#   kWhDelivered:
#     Q1 = 2.9910, Q3 = 11.5610, IQR = 8.5700
#     Lower bound = -9.8640, Upper bound = 24.4160
#     Outliers found: 890 (3.30%)
#
# ==================================================
# 📊 OUTLIER REMOVAL SUMMARY:
#   duration outliers removed: 443
#   charging_duration outliers removed: 1,981
#   kWhDelivered outliers removed: 890
#
# ✅ Before outlier removal: 31,424 rows
# ✅ After outlier removal: 26,067 rows
# ✅ Total rows removed: 5,357
#
# 📊 STATISTICS AFTER OUTLIER REMOVAL:
# +-------+-------------------+-------------------+-----------------+
# |summary|           duration|  charging_duration|     kWhDelivered|
# +-------+-------------------+-------------------+-----------------+
# |  count|              26067|              26067|            26067|
# |   mean|  4.965303139772324| 2.2775929868756863| 7.24799009002235|
# | stddev| 3.4794933285458214| 1.6239710144420403|5.143206867255436|
# |    min|0.07777777777777778|-0.6894444444444444|            0.501|
# |    max| 18.100833333333334|             7.5975|           24.389|
# +-------+-------------------+-------------------+-----------------+
#
#
# 📊 DATA QUALITY CHECK AFTER OUTLIER REMOVAL:
#   Negative duration: 0
#   Negative charging_duration: 23
#   Negative kWhDelivered: 0
#
# ✅ Remaining columns: 25 columns
# [Stage 110:==========================================>              (3 + 1) / 4]
# ✅ Row count: 26,067

# %%
print("="*70)
print("STEP 9: REMOVE MISSING VALUES & LOG TRANSFORM TARGET")
print("="*70)

from pyspark.sql.functions import col, sum as spark_sum, log1p
import numpy as np

# Paper: "Missing values, arising from feature engineering or lags, were removed"
# Paper: "log transform for the target to improve model fit (skewness = 1.09)"

# Bước 9.1: Kiểm tra missing values trước khi xóa
print("\n📊 MISSING VALUES BEFORE REMOVAL:")
missing_before = df_step8.select([
    spark_sum(col(c).isNull().cast("int")).alias(c) 
    for c in df_step8.columns if c not in ['connectionTime_utc', 'disconnectTime_utc', 'doneChargingTime_utc']
])
missing_before.show(vertical=True, truncate=False)

# Bước 9.2: Xóa các row có missing values
print("\n🗑️ REMOVING MISSING VALUES...")

# Các cột quan trọng không được phép có null
critical_cols = ['kWhDelivered', 'duration', 'charging_duration_log', 
                 'lag_1_log', 'lag_2_log', 'lag_3_log',
                 'rolling_mean_3_log', 'rolling_mean_5_log']

before_count = df_step8.count()
df_step9 = df_step8

for col_name in critical_cols:
    df_step9 = df_step9.filter(col(col_name).isNotNull())
    after_count = df_step9.count()
    if after_count < before_count:
        print(f"  Removed {before_count - after_count:,} rows with null in '{col_name}'")
        before_count = after_count

# Xóa các row có charging_duration âm (còn 23 cái)
df_step9 = df_step9.filter(col("charging_duration") >= 0)
print(f"  Removed {df_step8.count() - df_step9.count() - (df_step8.count() - before_count):,} rows with negative charging_duration")

print(f"\n✅ After removing missing values: {df_step9.count():,} rows")
print(f"✅ Total rows removed: {df_step8.count() - df_step9.count():,}")

# Bước 9.3: Kiểm tra lại missing values
print("\n📊 REMAINING NULLS (should be 0 for all columns):")
missing_after = df_step9.select([
    spark_sum(col(c).isNull().cast("int")).alias(c) 
    for c in critical_cols
])
missing_after.show(vertical=True, truncate=False)

# Bước 9.4: Log transform target variable (kWhDelivered)
print("\n📊 LOG TRANSFORM TARGET VARIABLE:")

# Kiểm tra skewness trước khi log transform
sample_pdf = df_step9.select("kWhDelivered").sample(0.1, seed=42).toPandas()
skewness_before = sample_pdf["kWhDelivered"].skew()
print(f"  Skewness before log transform: {skewness_before:.4f}")
print(f"  Paper reported skewness: 1.09")

# Log transform: log1p = log(1 + x)
df_step9 = df_step9.withColumn("kWhDelivered_log", log1p(col("kWhDelivered")))

# Kiểm tra skewness sau log transform
sample_pdf_after = df_step9.select("kWhDelivered_log").sample(0.1, seed=42).toPandas()
skewness_after = sample_pdf_after["kWhDelivered_log"].skew()
print(f"  Skewness after log transform: {skewness_after:.4f}")
print(f"  Improvement: {skewness_before - skewness_after:.4f}")

# Thống kê target
print("\n📊 TARGET STATISTICS:")
df_step9.select("kWhDelivered", "kWhDelivered_log").describe().show()

# Bước 9.5: Chỉ giữ các features đúng theo paper (17 features + target)
print("\n📋 SELECTING FINAL FEATURES (17 features + target):")

features_paper = [
    'hour', 'day_of_week', 'month', 'season',
    'duration', 'charging_duration', 'charging_duration_log',
    'hour_sin', 'hour_cos', 'day_of_year', 'week_of_year', 'is_holiday',
    'lag_1_log', 'lag_2_log', 'lag_3_log',
    'rolling_mean_3_log', 'rolling_mean_5_log'
]

# Kiểm tra xem có đủ features không
missing_features = [f for f in features_paper if f not in df_step9.columns]
if missing_features:
    print(f"  ⚠️ Missing features: {missing_features}")
else:
    print(f"  ✅ All 17 features present")

# Chọn final columns
final_columns = features_paper + ['kWhDelivered_log', 'connectionTime_utc']
df_final = df_step9.select(*final_columns)

print(f"\n✅ Final dataset: {df_final.count():,} rows, {len(df_final.columns)} columns")
print(f"✅ Features: {len(features_paper)}")
print(f"✅ Target: kWhDelivered_log")

# So sánh với paper
print(f"\n📊 COMPARISON WITH PAPER:")
print(f"  Paper's cleaned sessions: 14,496")
print(f"  Our cleaned sessions: {df_final.count():,}")
print(f"  Difference: {df_final.count() - 14496:,}")

# Hiển thị sample
print("\n📋 FINAL DATASET SAMPLE (first 5 rows):")
df_final.show(5, truncate=False)

print(f"\n✅ Final columns: {df_final.columns}")
# Out:
# ======================================================================
# STEP 9: REMOVE MISSING VALUES & LOG TRANSFORM TARGET
# ======================================================================
#
# 📊 MISSING VALUES BEFORE REMOVAL:
# 26/04/16 04:41:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:07 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# -RECORD 0---------------------------
#  kWhDelivered                 | 0
#  duration                     | 0
#  charging_duration            | 0
#  charging_duration_log        | 25
#  hour                         | 0
#  day_of_week                  | 0
#  month                        | 0
#  year                         | 0
#  day_of_year                  | 0
#  week_of_year                 | 0
#  season                       | 0
#  is_weekend                   | 0
#  is_holiday                   | 0
#  hour_sin                     | 0
#  hour_cos                     | 0
#  hour_charging_interaction    | 25
#  weekend_charging_interaction | 25
#  lag_1_log                    | 692
#  lag_2_log                    | 675
#  lag_3_log                    | 703
#  rolling_mean_3_log           | 117
#  rolling_mean_5_log           | 33
#
#
# 🗑️ REMOVING MISSING VALUES...
# 26/04/16 04:41:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Removed 25 rows with null in 'charging_duration_log'
# 26/04/16 04:41:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:16 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:17 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Removed 690 rows with null in 'lag_1_log'
# 26/04/16 04:41:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:18 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Removed 416 rows with null in 'lag_2_log'
# 26/04/16 04:41:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Removed 277 rows with null in 'lag_3_log'
# 26/04/16 04:41:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Removed 0 rows with negative charging_duration
# 26/04/16 04:41:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ✅ After removing missing values: 24,659 rows
# 26/04/16 04:41:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:30 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ✅ Total rows removed: 1,408
#
# 📊 REMAINING NULLS (should be 0 for all columns):
# 26/04/16 04:41:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:31 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# -RECORD 0--------------------
#  kWhDelivered          | 0
#  duration              | 0
#  charging_duration_log | 0
#  lag_1_log             | 0
#  lag_2_log             | 0
#  lag_3_log             | 0
#  rolling_mean_3_log    | 0
#  rolling_mean_5_log    | 0
#
#
# 📊 LOG TRANSFORM TARGET VARIABLE:
# 26/04/16 04:41:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:34 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:35 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Skewness before log transform: 0.6700
#   Paper reported skewness: 1.09
# 26/04/16 04:41:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:36 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Skewness after log transform: -0.4089
#   Improvement: 1.0789
#
# 📊 TARGET STATISTICS:
# 26/04/16 04:41:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:37 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------+------------------+------------------+
# |summary|      kWhDelivered|  kWhDelivered_log|
# +-------+------------------+------------------+
# |  count|             24659|             24659|
# |   mean|7.3350544649670155|1.8993908223829834|
# | stddev| 5.159768068134582|0.7048099265955429|
# |    min|             0.501|0.4061315526513249|
# |    max|            24.389|3.2343160093560788|
# +-------+------------------+------------------+
#
#
# 📋 SELECTING FINAL FEATURES (17 features + target):
#   ✅ All 17 features present
# 26/04/16 04:41:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:38 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:39 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ✅ Final dataset: 24,659 rows, 19 columns
# ✅ Features: 17
# ✅ Target: kWhDelivered_log
#
# 📊 COMPARISON WITH PAPER:
#   Paper's cleaned sessions: 14,496
# 26/04/16 04:41:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Our cleaned sessions: 24,659
# 26/04/16 04:41:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Difference: 10,163
#
# 📋 FINAL DATASET SAMPLE (first 5 rows):
# 26/04/16 04:41:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:41 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +----+-----------+-----+------+------------------+------------------+---------------------+-------------------+-------------------+-----------+------------+----------+------------------+------------------+------------------+------------------+------------------+-----------------+-------------------+
# |hour|day_of_week|month|season|duration          |charging_duration |charging_duration_log|hour_sin           |hour_cos           |day_of_year|week_of_year|is_holiday|lag_1_log         |lag_2_log         |lag_3_log         |rolling_mean_3_log|rolling_mean_5_log|kWhDelivered_log |connectionTime_utc |
# +----+-----------+-----+------+------------------+------------------+---------------------+-------------------+-------------------+-----------+------------+----------+------------------+------------------+------------------+------------------+------------------+-----------------+-------------------+
# |14  |3          |4    |1     |9.307777777777778 |1.471111111111111 |0.9046678920461622   |-0.4999999999999997|-0.8660254037844388|115        |17          |0         |0.7411433788282008|1.3824676039712638|1.168863627212368 |1.0974915366706108|1.0974915366706108|1.820832716713762|2018-04-25 14:37:06|
# |14  |3          |4    |1     |8.377222222222223 |2.9988888888888887|1.38601654475472     |-0.4999999999999997|-0.8660254037844388|115        |17          |0         |0.9046678920461622|0.7411433788282008|1.3824676039712638|1.009426291615209 |1.0492856255144987|2.408655356721112|2018-04-25 14:40:34|
# |14  |3          |4    |1     |10.561111111111112|1.5772222222222223|0.9467121608674877   |-0.4999999999999997|-0.8660254037844388|115        |17          |0         |1.38601654475472  |0.9046678920461622|0.7411433788282008|1.010609271876361 |1.116631809362543 |2.187174241482718|2018-04-25 14:43:50|
# |14  |3          |4    |1     |3.6691666666666665|3.6666666666666665|1.5404450409471488   |-0.4999999999999997|-0.8660254037844388|115        |17          |0         |0.9467121608674877|1.38601654475472  |0.9046678920461622|1.07913219922279  |1.072201516093567 |2.79079694188845 |2018-04-25 14:47:42|
# |14  |3          |4    |1     |4.134444444444444 |1.8344444444444445|1.0418459548175008   |-0.4999999999999997|-0.8660254037844388|115        |17          |0         |1.5404450409471488|0.9467121608674877|1.38601654475472  |1.2910579155231188|1.103797003488744 |2.073549215974998|2018-04-25 14:58:25|
# +----+-----------+-----+------+------------------+------------------+---------------------+-------------------+-------------------+-----------+------------+----------+------------------+------------------+------------------+------------------+------------------+-----------------+-------------------+
# only showing top 5 rows
#
#
# ✅ Final columns: ['hour', 'day_of_week', 'month', 'season', 'duration', 'charging_duration', 'charging_duration_log', 'hour_sin', 'hour_cos', 'day_of_year', 'week_of_year', 'is_holiday', 'lag_1_log', 'lag_2_log', 'lag_3_log', 'rolling_mean_3_log', 'rolling_mean_5_log', 'kWhDelivered_log', 'connectionTime_utc']

# %%
print("="*70)
print("STEP 10: TRAIN/TEST SPLIT (TEMPORAL ORDER - NO SHUFFLE)")
print("="*70)

# Sắp xếp theo thời gian
df_ordered = df_final.orderBy("connectionTime_utc")

total_rows = df_ordered.count()
train_size = int(total_rows * 0.8)

print(f"Total: {total_rows:,}")
print(f"Train (80%): {train_size:,}")
print(f"Test (20%): {total_rows - train_size:,}")

# Đánh index theo thứ tự thời gian
window_order = Window.orderBy("connectionTime_utc")
df_with_index = df_ordered.withColumn("row_num", row_number().over(window_order))

# Split theo temporal order
train_df = df_with_index.filter(col("row_num") <= train_size).drop("row_num", "connectionTime_utc")
test_df = df_with_index.filter(col("row_num") > train_size).drop("row_num", "connectionTime_utc")

print(f"\n✅ Train: {train_df.count():,} rows")
print(f"✅ Test: {test_df.count():,} rows")
# Out:
# 26/04/16 04:41:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ======================================================================
# STEP 10: TRAIN/TEST SPLIT (TEMPORAL ORDER - NO SHUFFLE)
# ======================================================================
# 26/04/16 04:41:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# Total: 24,659
# Train (80%): 19,727
# Test (20%): 4,932
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:44 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ✅ Train: 19,727 rows
# 26/04/16 04:41:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:45 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:46 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ✅ Test: 4,932 rows

# %%
print("="*70)
print("STEP 10b: DATA LEAKAGE CHECK")
print("="*70)

# Tạo hash cho mỗi hàng
from pyspark.sql.functions import concat_ws, sha2

train_hashes = train_df.select(
    sha2(concat_ws("|", *train_df.columns), 256).alias("row_hash")
).distinct()

test_hashes = test_df.select(
    sha2(concat_ws("|", *test_df.columns), 256).alias("row_hash")
).distinct()

overlap = train_hashes.intersect(test_hashes)
overlap_count = overlap.count()

print(f"  Overlap rows: {overlap_count:,}")
if overlap_count == 0:
    print("  ✅ No data leakage detected!")
else:
    print("  ❌ Data leakage detected!")
# Out:
# ======================================================================
# STEP 10b: DATA LEAKAGE CHECK
# ======================================================================
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:41:59 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:42:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:42:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:42:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:42:00 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#   Overlap rows: 0
#   ✅ No data leakage detected!

# %%
print("="*70)
print("TRAIN GBT REGRESSOR (Spark ML)")
print("="*70)

from pyspark.ml.regression import GBTRegressor
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline

# Features (17 features)
feature_cols = [
    'hour', 'day_of_week', 'month', 'season',
    'duration', 'charging_duration', 'charging_duration_log',
    'hour_sin', 'hour_cos', 'day_of_year', 'week_of_year', 'is_holiday',
    'lag_1_log', 'lag_2_log', 'lag_3_log',
    'rolling_mean_3_log', 'rolling_mean_5_log'
]

# Target
target_col = 'kWhDelivered_log'

# Pipeline
assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
scaler = StandardScaler(inputCol="features", outputCol="scaled_features", withStd=True, withMean=True)
gbt = GBTRegressor(featuresCol="scaled_features", labelCol=target_col, maxDepth=10, maxIter=100, seed=42)

pipeline = Pipeline(stages=[assembler, scaler, gbt])

# Train
model = pipeline.fit(train_df)

# Predict
predictions = model.transform(test_df)

# Evaluate
evaluator = RegressionEvaluator(labelCol=target_col, predictionCol="prediction", metricName="rmse")
rmse_log = evaluator.evaluate(predictions)

print(f"RMSE (log scale): {rmse_log:.4f}")
print(f"RMSE (kWh): {np.expm1(rmse_log):.4f}")
# Out:
# ======================================================================
# TRAIN GBT REGRESSOR (Spark ML)
# ======================================================================
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:43:47 WARN DAGScheduler: Broadcasting large task binary with size 1010.6 KiB
# 26/04/16 04:43:47 WARN DAGScheduler: Broadcasting large task binary with size 1006.1 KiB
# 26/04/16 04:43:47 WARN DAGScheduler: Broadcasting large task binary with size 1006.6 KiB
# 26/04/16 04:43:47 WARN DAGScheduler: Broadcasting large task binary with size 1007.3 KiB
# 26/04/16 04:43:48 WARN DAGScheduler: Broadcasting large task binary with size 1008.3 KiB
# 26/04/16 04:43:48 WARN DAGScheduler: Broadcasting large task binary with size 1010.5 KiB
# 26/04/16 04:43:48 WARN DAGScheduler: Broadcasting large task binary with size 1014.7 KiB
# 26/04/16 04:43:48 WARN DAGScheduler: Broadcasting large task binary with size 1022.9 KiB
# 26/04/16 04:43:48 WARN DAGScheduler: Broadcasting large task binary with size 1038.3 KiB
# 26/04/16 04:43:48 WARN DAGScheduler: Broadcasting large task binary with size 1067.3 KiB
# 26/04/16 04:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1114.5 KiB
# 26/04/16 04:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1111.7 KiB
# 26/04/16 04:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1112.2 KiB
# 26/04/16 04:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1112.9 KiB
# 26/04/16 04:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1113.9 KiB
# 26/04/16 04:43:49 WARN DAGScheduler: Broadcasting large task binary with size 1116.2 KiB
# 26/04/16 04:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1120.7 KiB
# 26/04/16 04:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1128.9 KiB
# 26/04/16 04:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1144.7 KiB
# 26/04/16 04:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1173.5 KiB
# 26/04/16 04:43:50 WARN DAGScheduler: Broadcasting large task binary with size 1225.3 KiB
# 26/04/16 04:43:51 WARN DAGScheduler: Broadcasting large task binary with size 1226.4 KiB
# 26/04/16 04:43:51 WARN DAGScheduler: Broadcasting large task binary with size 1226.9 KiB
# 26/04/16 04:43:51 WARN DAGScheduler: Broadcasting large task binary with size 1227.6 KiB
# 26/04/16 04:43:51 WARN DAGScheduler: Broadcasting large task binary with size 1228.6 KiB
# 26/04/16 04:43:51 WARN DAGScheduler: Broadcasting large task binary with size 1230.9 KiB
# 26/04/16 04:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1235.4 KiB
# 26/04/16 04:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1243.5 KiB
# 26/04/16 04:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1257.9 KiB
# 26/04/16 04:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1282.9 KiB
# 26/04/16 04:43:52 WARN DAGScheduler: Broadcasting large task binary with size 1325.9 KiB
# 26/04/16 04:43:53 WARN DAGScheduler: Broadcasting large task binary with size 1324.8 KiB
# 26/04/16 04:43:53 WARN DAGScheduler: Broadcasting large task binary with size 1325.3 KiB
# 26/04/16 04:43:53 WARN DAGScheduler: Broadcasting large task binary with size 1326.0 KiB
# 26/04/16 04:43:53 WARN DAGScheduler: Broadcasting large task binary with size 1327.0 KiB
# 26/04/16 04:43:53 WARN DAGScheduler: Broadcasting large task binary with size 1329.2 KiB
# 26/04/16 04:43:53 WARN DAGScheduler: Broadcasting large task binary with size 1333.8 KiB
# 26/04/16 04:43:54 WARN DAGScheduler: Broadcasting large task binary with size 1342.5 KiB
# 26/04/16 04:43:54 WARN DAGScheduler: Broadcasting large task binary with size 1359.1 KiB
# 26/04/16 04:43:54 WARN DAGScheduler: Broadcasting large task binary with size 1388.1 KiB
# 26/04/16 04:43:54 WARN DAGScheduler: Broadcasting large task binary with size 1438.7 KiB
# 26/04/16 04:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1438.2 KiB
# 26/04/16 04:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1438.6 KiB
# 26/04/16 04:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1439.4 KiB
# 26/04/16 04:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1440.3 KiB
# 26/04/16 04:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1442.6 KiB
# 26/04/16 04:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1447.1 KiB
# 26/04/16 04:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1455.9 KiB
# 26/04/16 04:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1473.2 KiB
# 26/04/16 04:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1504.4 KiB
# 26/04/16 04:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1556.1 KiB
# 26/04/16 04:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1555.6 KiB
# 26/04/16 04:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1556.1 KiB
# 26/04/16 04:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1556.8 KiB
# 26/04/16 04:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1557.8 KiB
# 26/04/16 04:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1560.1 KiB
# 26/04/16 04:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1564.5 KiB
# 26/04/16 04:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1572.5 KiB
# 26/04/16 04:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1585.7 KiB
# 26/04/16 04:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1607.2 KiB
# 26/04/16 04:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1638.7 KiB
# 26/04/16 04:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1633.5 KiB
# 26/04/16 04:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1633.9 KiB
# 26/04/16 04:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1634.6 KiB
# 26/04/16 04:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1635.6 KiB
# 26/04/16 04:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1637.9 KiB
# 26/04/16 04:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1642.4 KiB
# 26/04/16 04:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1651.2 KiB
# 26/04/16 04:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1668.0 KiB
# 26/04/16 04:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1698.2 KiB
# 26/04/16 04:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1750.2 KiB
# 26/04/16 04:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1748.3 KiB
# 26/04/16 04:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 26/04/16 04:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1749.5 KiB
# 26/04/16 04:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1750.5 KiB
# 26/04/16 04:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1752.8 KiB
# 26/04/16 04:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1757.2 KiB
# 26/04/16 04:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1765.3 KiB
# 26/04/16 04:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1779.7 KiB
# 26/04/16 04:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1805.4 KiB
# 26/04/16 04:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1849.2 KiB
# 26/04/16 04:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1848.5 KiB
# 26/04/16 04:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1849.0 KiB
# 26/04/16 04:44:13 WARN DAGScheduler: Broadcasting large task binary with size 1849.7 KiB
# 26/04/16 04:44:14 WARN DAGScheduler: Broadcasting large task binary with size 1850.7 KiB
# 26/04/16 04:44:14 WARN DAGScheduler: Broadcasting large task binary with size 1853.0 KiB
# 26/04/16 04:44:14 WARN DAGScheduler: Broadcasting large task binary with size 1857.3 KiB
# 26/04/16 04:44:14 WARN DAGScheduler: Broadcasting large task binary with size 1865.7 KiB
# 26/04/16 04:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1882.6 KiB
# 26/04/16 04:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1913.8 KiB
# 26/04/16 04:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1966.2 KiB
# 26/04/16 04:44:15 WARN DAGScheduler: Broadcasting large task binary with size 1967.5 KiB
# 26/04/16 04:44:16 WARN DAGScheduler: Broadcasting large task binary with size 1967.9 KiB
# 26/04/16 04:44:16 WARN DAGScheduler: Broadcasting large task binary with size 1968.7 KiB
# 26/04/16 04:44:16 WARN DAGScheduler: Broadcasting large task binary with size 1969.7 KiB
# 26/04/16 04:44:16 WARN DAGScheduler: Broadcasting large task binary with size 1971.9 KiB
# 26/04/16 04:44:16 WARN DAGScheduler: Broadcasting large task binary with size 1976.5 KiB
# 26/04/16 04:44:17 WARN DAGScheduler: Broadcasting large task binary with size 1985.5 KiB
# 26/04/16 04:44:17 WARN DAGScheduler: Broadcasting large task binary with size 2003.2 KiB
# 26/04/16 04:44:17 WARN DAGScheduler: Broadcasting large task binary with size 2033.6 KiB
# 26/04/16 04:44:17 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:18 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:18 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:18 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:18 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:19 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:19 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/04/16 04:44:19 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 26/04/16 04:44:19 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 26/04/16 04:44:19 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 26/04/16 04:44:19 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:20 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:20 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:21 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:21 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:21 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:21 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:22 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:23 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:23 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:23 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:24 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:24 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:24 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:24 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:25 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:25 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:25 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 26/04/16 04:44:25 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:25 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:26 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:26 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:26 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:27 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:27 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:27 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:27 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:27 WARN DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 26/04/16 04:44:28 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:28 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:28 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:29 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:29 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:29 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:30 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:30 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:30 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:30 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:30 WARN DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 26/04/16 04:44:30 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:32 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:32 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:32 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:32 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:33 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:33 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:34 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:34 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:34 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:34 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 26/04/16 04:44:34 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:35 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:35 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:35 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:35 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:36 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:36 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:36 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:36 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:37 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 26/04/16 04:44:37 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:37 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:37 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:37 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:38 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:38 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:38 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:38 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:39 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:39 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 26/04/16 04:44:39 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:40 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:40 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:40 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:40 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:42 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:42 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:43 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 26/04/16 04:44:43 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:43 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:45 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:45 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:45 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:45 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 26/04/16 04:44:46 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:46 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:46 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:46 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:48 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 26/04/16 04:44:48 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:48 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:50 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:51 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:51 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:51 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 26/04/16 04:44:51 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:52 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:52 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 26/04/16 04:44:54 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:55 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:55 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:56 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:56 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:56 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:56 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:57 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:57 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:57 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:57 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 26/04/16 04:44:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:44:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:44:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:44:58 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:44:59 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:44:59 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:44:59 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:45:00 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:45:01 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:45:01 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 26/04/16 04:45:01 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:01 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:02 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:02 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:02 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:02 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:02 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:03 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:03 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:03 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/04/16 04:45:04 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:04 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:04 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:04 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:05 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:05 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:06 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:06 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:06 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:06 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 26/04/16 04:45:07 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:07 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:07 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:08 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:08 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:08 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:08 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:08 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:09 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:09 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:09 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:10 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:10 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:10 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:10 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 26/04/16 04:45:11 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:11 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:11 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:12 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:12 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:12 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:13 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:13 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:13 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:14 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/04/16 04:45:14 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:14 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:14 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:15 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:15 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:15 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:16 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:16 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:16 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:17 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:17 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:17 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:17 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:18 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 26/04/16 04:45:18 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:18 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:19 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:19 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:19 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:19 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:20 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:20 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:20 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:21 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 26/04/16 04:45:21 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:21 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:22 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:22 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:22 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:23 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:23 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:23 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:23 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:24 WARN DAGScheduler: Broadcasting large task binary with size 4.1 MiB
# 26/04/16 04:45:24 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:24 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:25 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:25 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:25 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:26 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:26 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:26 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:26 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:27 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:27 WARN DAGScheduler: Broadcasting large task binary with size 4.2 MiB
# 26/04/16 04:45:28 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:28 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:29 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:29 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:29 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:29 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:30 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:30 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:31 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:31 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/04/16 04:45:31 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:32 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:32 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:32 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:32 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:33 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:33 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:33 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:34 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:34 WARN DAGScheduler: Broadcasting large task binary with size 4.4 MiB
# 26/04/16 04:45:34 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:35 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:35 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:35 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:36 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:36 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:36 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:37 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:37 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:37 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 26/04/16 04:45:38 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:38 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:38 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:39 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:39 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:39 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:40 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:40 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:40 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:41 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:41 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:41 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:42 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:42 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:42 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:43 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:43 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# 26/04/16 04:45:43 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 26/04/16 04:45:44 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 26/04/16 04:45:44 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# 26/04/16 04:45:44 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:45 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:45 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:46 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:46 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:46 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:47 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:47 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:47 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:48 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:48 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:49 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:49 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:49 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:50 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:50 WARN DAGScheduler: Broadcasting large task binary with size 4.8 MiB
# 26/04/16 04:45:50 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:51 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:51 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:51 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:52 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:52 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:52 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:53 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:53 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:53 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:54 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:54 WARN DAGScheduler: Broadcasting large task binary with size 4.9 MiB
# 26/04/16 04:45:54 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:55 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:55 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:56 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:56 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:56 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:57 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:57 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:57 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:57 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:58 WARN DAGScheduler: Broadcasting large task binary with size 5.0 MiB
# 26/04/16 04:45:58 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:45:59 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:45:59 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:00 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:00 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:00 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:01 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:01 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:01 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:02 WARN DAGScheduler: Broadcasting large task binary with size 5.1 MiB
# 26/04/16 04:46:02 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:03 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:03 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:03 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:04 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:04 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:05 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:05 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:05 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:06 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 26/04/16 04:46:07 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:07 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:07 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:08 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:08 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:09 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:09 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:09 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:10 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:10 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 26/04/16 04:46:11 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:11 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:12 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:12 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:12 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:13 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:13 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:13 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:14 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:14 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 26/04/16 04:46:14 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:15 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:16 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:16 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:16 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:17 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:17 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:17 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:18 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:18 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:18 WARN DAGScheduler: Broadcasting large task binary with size 5.5 MiB
# 26/04/16 04:46:19 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:19 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:20 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:20 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:20 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:21 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:21 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:22 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:22 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:22 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 26/04/16 04:46:23 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:23 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:24 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:24 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:24 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:25 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:25 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:26 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:26 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# 26/04/16 04:46:26 WARN DAGScheduler: Broadcasting large task binary with size 5.7 MiB
# ...
# 26/04/16 04:48:29 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:30 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:30 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:31 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:32 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:33 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:33 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:34 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:34 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:35 WARN DAGScheduler: Broadcasting large task binary with size 8.3 MiB
# 26/04/16 04:48:35 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:36 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:37 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:37 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:39 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:39 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:40 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:40 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:41 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:41 WARN DAGScheduler: Broadcasting large task binary with size 8.4 MiB
# 26/04/16 04:48:42 WARN DAGScheduler: Broadcasting large task binary with size 8.5 MiB
# 26/04/16 04:48:43 WARN DAGScheduler: Broadcasting large task binary with size 8.5 MiB
# 26/04/16 04:48:44 WARN DAGScheduler: Broadcasting large task binary with size 8.5 MiB
# 26/04/16 04:48:44 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:45 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:46 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:46 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:47 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:47 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:48 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:48 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:49 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:50 WARN DAGScheduler: Broadcasting large task binary with size 8.6 MiB
# 26/04/16 04:48:50 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:51 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:52 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:52 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:52 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:53 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:54 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:54 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:55 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:56 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:56 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:57 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:57 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:58 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:59 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:48:59 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:49:00 WARN DAGScheduler: Broadcasting large task binary with size 8.7 MiB
# 26/04/16 04:49:00 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:01 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:01 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:02 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:03 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:03 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:04 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:05 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:05 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:06 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:06 WARN DAGScheduler: Broadcasting large task binary with size 8.8 MiB
# 26/04/16 04:49:07 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:07 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:08 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:09 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:10 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:10 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:10 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:11 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:12 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:12 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:13 WARN DAGScheduler: Broadcasting large task binary with size 8.9 MiB
# 26/04/16 04:49:13 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:14 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:15 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:16 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:16 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:17 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:17 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:18 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:19 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:19 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:20 WARN DAGScheduler: Broadcasting large task binary with size 9.0 MiB
# 26/04/16 04:49:20 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:21 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:22 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:23 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:23 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:24 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:24 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:25 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:26 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:27 WARN DAGScheduler: Broadcasting large task binary with size 9.1 MiB
# 26/04/16 04:49:27 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:28 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:29 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:29 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:29 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:30 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:31 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:31 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:32 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:33 WARN DAGScheduler: Broadcasting large task binary with size 9.2 MiB
# 26/04/16 04:49:34 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:35 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:35 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:36 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:37 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:37 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:38 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:38 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:39 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:40 WARN DAGScheduler: Broadcasting large task binary with size 9.3 MiB
# 26/04/16 04:49:41 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:42 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:42 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:43 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:43 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:44 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:45 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:45 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:46 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:46 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:47 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:48 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:48 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:49 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:50 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:50 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:51 WARN DAGScheduler: Broadcasting large task binary with size 9.4 MiB
# 26/04/16 04:49:51 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:52 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:53 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:53 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:54 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:55 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:55 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:56 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:56 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:57 WARN DAGScheduler: Broadcasting large task binary with size 9.5 MiB
# 26/04/16 04:49:58 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 26/04/16 04:49:58 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 26/04/16 04:49:59 WARN DAGScheduler: Broadcasting large task binary with size 9.6 MiB
# 26/04/16 04:50:00 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:00 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:01 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:02 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:03 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:03 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:04 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:04 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:05 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:06 WARN DAGScheduler: Broadcasting large task binary with size 9.7 MiB
# 26/04/16 04:50:06 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:07 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:08 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:09 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:09 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:10 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:10 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:11 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:11 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:12 WARN DAGScheduler: Broadcasting large task binary with size 9.8 MiB
# 26/04/16 04:50:13 WARN DAGScheduler: Broadcasting large task binary with size 9.9 MiB
# 26/04/16 04:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:14 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:15 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/04/16 04:50:16 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/04/16 04:50:16 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# [Stage 3213:>                                                       (0 + 1) / 1]
# RMSE (log scale): 0.6113
# RMSE (kWh): 0.8428
